# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from api_keys import weather_api_key
from citipy import citipy
import random
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# create random list of coordinates

latitude_list = []
longitude_list = []
desired_length = 500

for i in range(0,desired_length*4):
    n = random.uniform(-90, 90)
    latitude_list.append(n)

for j in range(0,desired_length*4):
    n = random.uniform(-180, 180)
    longitude_list.append(n)

# %%
# create list of unique cities from the coordinates

city_list = []

for lat, lng in zip(latitude_list, longitude_list):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in city_list:
        city_list.append(city)

print(len(city_list))

#url = "http://api.openweathermap.org/data/2.5/weather?"
#units = "imperial"
#city = "marawi"
#query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
#weather_response = requests.get(query_url)
#weather_json = weather_response.json()
#print(json.dumps(weather_json, indent=4))
# Out:
# 765

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create lists to hold data

city_id_list = []
cityname_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_list = []
city_id = 0

# save info for api

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# loop through each city and pull info

for city in city_list:
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    if weather_json["cod"] == 200:
        city_id_list.append(city_id)
        cityname_list.append(city)
        cloudiness_list.append(weather_json["clouds"]["all"])
        country_list.append(weather_json["sys"]["country"])
        date_list.append(weather_json["dt"])
        humidity_list.append(weather_json["main"]["humidity"])
        lat_list.append(weather_json["coord"]["lat"])
        lng_list.append(weather_json["coord"]["lon"])
        max_temp_list.append(weather_json["main"]["temp_max"])
        wind_list.append(weather_json["wind"]["speed"])
        print(f"City ID: {city_id}, City Name: {city}")
        city_id += 1
    time.sleep(2)
# Out:
# City ID: 0, City Name: saumur
# City ID: 1, City Name: hualmay
# City ID: 2, City Name: hobart
# City ID: 3, City Name: esperance
# City ID: 4, City Name: praia
# City ID: 5, City Name: shirvan
# City ID: 6, City Name: busselton
# City ID: 7, City Name: cape town
# City ID: 8, City Name: barrow
# City ID: 9, City Name: portland
# City ID: 10, City Name: inhambane
# City ID: 11, City Name: pangnirtung
# City ID: 12, City Name: bilma
# City ID: 13, City Name: rikitea
# City ID: 14, City Name: ushuaia
# City ID: 15, City Name: khatanga
# City ID: 16, City Name: riberalta
# City ID: 17, City Name: toropets
# City ID: 18, City Name: vaini
# City ID: 19, City Name: bilibino
# City ID: 20, City Name: klaksvik
# City ID: 21, City Name: rock springs
# City ID: 22, City Name: puerto ayora
# City ID: 23, City Name: mudon
# City ID: 24, City Name: kaitangata
# City ID: 25, City Name: killybegs
# City ID: 26, City Name: eydhafushi
# City ID: 27, City Name: hermanus
# City ID: 28, City Name: kiama
# City ID: 29, City Name: kuningan
# City ID: 30, City Name: longyearbyen
# City ID: 31, City Name: adrar
# City ID: 32, City Name: mar del plata
# City ID: 33, City Name: port alfred
# City ID: 34, City Name: plouzane
# City ID: 35, City Name: cidreira
# City ID: 36, City Name: kahului
# City ID: 37, City Name: kande
# City ID: 38, City Name: dikson
# City ID: 39, City Name: plettenberg bay
# City ID: 40, City Name: jamestown
# City ID: 41, City Name: pevek
# City ID: 42, City Name: hasilpur
# City ID: 43, City Name: ponta do sol
# City ID: 44, City Name: fethiye
# City ID: 45, City Name: butaritari
# City ID: 46, City Name: katsuura
# City ID: 47, City Name: wewak
# City ID: 48, City Name: kapaa
# City ID: 49, City Name: yerbogachen
# City ID: 50, City Name: krasne
# City ID: 51, City Name: olupona
# City ID: 52, City Name: oranjestad
# City ID: 53, City Name: lebu
# City ID: 54, City Name: ranong
# City ID: 55, City Name: marawi
# City ID: 56, City Name: byron bay
# City ID: 57, City Name: coihaique
# City ID: 58, City Name: jahangirpur
# City ID: 59, City Name: tasiilaq
# City ID: 60, City Name: tuatapere
# City ID: 61, City Name: nanortalik
# City ID: 62, City Name: talara
# City ID: 63, City Name: bredasdorp
# City ID: 64, City Name: bathsheba
# City ID: 65, City Name: mataura
# City ID: 66, City Name: progreso
# City ID: 67, City Name: talnakh
# City ID: 68, City Name: matamoros
# City ID: 69, City Name: sorland
# City ID: 70, City Name: avarua
# City ID: 71, City Name: guerrero negro
# City ID: 72, City Name: lugovoy
# City ID: 73, City Name: casino
# City ID: 74, City Name: talikota
# City ID: 75, City Name: carnarvon
# City ID: 76, City Name: codrington
# City ID: 77, City Name: rocha
# City ID: 78, City Name: tigzirt
# City ID: 79, City Name: punta arenas
# City ID: 80, City Name: mandera
# City ID: 81, City Name: labuhan
# City ID: 82, City Name: castro
# City ID: 83, City Name: det udom
# City ID: 84, City Name: kununurra
# City ID: 85, City Name: rawson
# City ID: 86, City Name: qasigiannguit
# City ID: 87, City Name: hithadhoo
# City ID: 88, City Name: qaanaaq
# City ID: 89, City Name: new norfolk
# City ID: 90, City Name: gat
# City ID: 91, City Name: kodiak
# City ID: 92, City Name: kokkola
# City ID: 93, City Name: manjacaze
# City ID: 94, City Name: lumsden
# City ID: 95, City Name: mount isa
# City ID: 96, City Name: palu
# City ID: 97, City Name: lucea
# City ID: 98, City Name: smithfield
# City ID: 99, City Name: vestmanna
# City ID: 100, City Name: nelson bay
# City ID: 101, City Name: kalangala
# City ID: 102, City Name: touros
# City ID: 103, City Name: merauke
# City ID: 104, City Name: arraial do cabo
# City ID: 105, City Name: gatbo
# City ID: 106, City Name: margate
# City ID: 107, City Name: bereda
# City ID: 108, City Name: mercedes
# City ID: 109, City Name: yayva
# City ID: 110, City Name: khandyga
# City ID: 111, City Name: verkhoyansk
# City ID: 112, City Name: richards bay
# City ID: 113, City Name: sinisian
# City ID: 114, City Name: bardiyah
# City ID: 115, City Name: belyy yar
# City ID: 116, City Name: orocue
# City ID: 117, City Name: rio grande
# City ID: 118, City Name: arona
# City ID: 119, City Name: kruisfontein
# City ID: 120, City Name: marsh harbour
# City ID: 121, City Name: alekseyevsk
# City ID: 122, City Name: sitka
# City ID: 123, City Name: batagay-alyta
# City ID: 124, City Name: lermontovka
# City ID: 125, City Name: abong mbang
# City ID: 126, City Name: ahipara
# City ID: 127, City Name: bambous virieux
# City ID: 128, City Name: dauphin
# City ID: 129, City Name: mumford
# City ID: 130, City Name: komsomolskiy
# City ID: 131, City Name: port hawkesbury
# City ID: 132, City Name: provideniya
# City ID: 133, City Name: nemuro
# City ID: 134, City Name: geraldton
# City ID: 135, City Name: koumra
# City ID: 136, City Name: port hardy
# City ID: 137, City Name: rabo de peixe
# City ID: 138, City Name: ilulissat
# City ID: 139, City Name: sijunjung
# City ID: 140, City Name: kibondo
# City ID: 141, City Name: ribeira grande
# City ID: 142, City Name: bluff
# City ID: 143, City Name: sakti
# City ID: 144, City Name: tromso
# City ID: 145, City Name: alofi
# City ID: 146, City Name: ola
# City ID: 147, City Name: ixtapa
# City ID: 148, City Name: kailua
# City ID: 149, City Name: cockburn town
# City ID: 150, City Name: magistralnyy
# City ID: 151, City Name: lagoa
# City ID: 152, City Name: santa maria
# City ID: 153, City Name: la ronge
# City ID: 154, City Name: majene
# City ID: 155, City Name: thompson
# City ID: 156, City Name: ornskoldsvik
# City ID: 157, City Name: yamunanagar
# City ID: 158, City Name: albany
# City ID: 159, City Name: havoysund
# City ID: 160, City Name: georgetown
# City ID: 161, City Name: asyut
# City ID: 162, City Name: tongchuan
# City ID: 163, City Name: lavrentiya
# City ID: 164, City Name: kon tum
# City ID: 165, City Name: yellowknife
# City ID: 166, City Name: chokurdakh
# City ID: 167, City Name: cherskiy
# City ID: 168, City Name: tessalit
# City ID: 169, City Name: torbay
# City ID: 170, City Name: racine
# City ID: 171, City Name: westport
# City ID: 172, City Name: whitehorse
# City ID: 173, City Name: tobermory
# City ID: 174, City Name: ossora
# City ID: 175, City Name: lubango
# City ID: 176, City Name: pangoa
# City ID: 177, City Name: shagonar
# City ID: 178, City Name: cabo san lucas
# City ID: 179, City Name: tula
# City ID: 180, City Name: kasongo-lunda
# City ID: 181, City Name: lasa
# City ID: 182, City Name: sao filipe
# City ID: 183, City Name: puerto del rosario
# City ID: 184, City Name: opuwo
# City ID: 185, City Name: victoria
# City ID: 186, City Name: krasnyy kommunar
# City ID: 187, City Name: high level
# City ID: 188, City Name: walsrode
# City ID: 189, City Name: kingman
# City ID: 190, City Name: sao felix do xingu
# City ID: 191, City Name: la macarena
# City ID: 192, City Name: kushiro
# City ID: 193, City Name: tiarei
# City ID: 194, City Name: grand gaube
# City ID: 195, City Name: hilo
# City ID: 196, City Name: zhezkazgan
# City ID: 197, City Name: wajima
# City ID: 198, City Name: constantine
# City ID: 199, City Name: bethel
# City ID: 200, City Name: port blair
# City ID: 201, City Name: hamilton
# City ID: 202, City Name: paracuru
# City ID: 203, City Name: meulaboh
# City ID: 204, City Name: souillac
# City ID: 205, City Name: salalah
# City ID: 206, City Name: norman wells
# City ID: 207, City Name: san jose
# City ID: 208, City Name: faya
# City ID: 209, City Name: port hedland
# City ID: 210, City Name: henties bay
# City ID: 211, City Name: barguzin
# City ID: 212, City Name: empalme
# City ID: 213, City Name: honiara
# City ID: 214, City Name: teya
# City ID: 215, City Name: saint-philippe
# City ID: 216, City Name: ewa beach
# City ID: 217, City Name: saskylakh
# City ID: 218, City Name: vestmannaeyjar
# City ID: 219, City Name: orchard homes
# City ID: 220, City Name: ayan
# City ID: 221, City Name: san policarpo
# City ID: 222, City Name: puerto escondido
# City ID: 223, City Name: husavik
# City ID: 224, City Name: marsa matruh
# City ID: 225, City Name: naron
# City ID: 226, City Name: vostok
# City ID: 227, City Name: vzmorye
# City ID: 228, City Name: fare
# City ID: 229, City Name: soe
# City ID: 230, City Name: pisco
# City ID: 231, City Name: mahajanga
# City ID: 232, City Name: mount pleasant
# City ID: 233, City Name: atar
# City ID: 234, City Name: asau
# City ID: 235, City Name: togul
# City ID: 236, City Name: poum
# City ID: 237, City Name: nioro
# City ID: 238, City Name: nome
# City ID: 239, City Name: celestun
# City ID: 240, City Name: marang
# City ID: 241, City Name: saint john
# City ID: 242, City Name: severo-kurilsk
# City ID: 243, City Name: east london
# City ID: 244, City Name: kipini
# City ID: 245, City Name: wilson
# City ID: 246, City Name: jawhar
# City ID: 247, City Name: tiksi
# City ID: 248, City Name: atuona
# City ID: 249, City Name: te anau
# City ID: 250, City Name: port elizabeth
# City ID: 251, City Name: kiunga
# City ID: 252, City Name: puro
# City ID: 253, City Name: udachnyy
# City ID: 254, City Name: yumen
# City ID: 255, City Name: isangel
# City ID: 256, City Name: wellington
# City ID: 257, City Name: brenham
# City ID: 258, City Name: sulangan
# City ID: 259, City Name: kashi
# City ID: 260, City Name: sorong
# City ID: 261, City Name: dingle
# City ID: 262, City Name: lingdong
# City ID: 263, City Name: korla
# City ID: 264, City Name: lufilufi
# City ID: 265, City Name: zemio
# City ID: 266, City Name: chuy
# City ID: 267, City Name: butterworth
# City ID: 268, City Name: nanyuki
# City ID: 269, City Name: pouembout
# City ID: 270, City Name: mantua
# City ID: 271, City Name: creel
# City ID: 272, City Name: pangody
# City ID: 273, City Name: carlsbad
# City ID: 274, City Name: deputatskiy
# City ID: 275, City Name: nainpur
# City ID: 276, City Name: upernavik
# City ID: 277, City Name: hasaki
# City ID: 278, City Name: ketchikan
# City ID: 279, City Name: chara
# City ID: 280, City Name: saint-pierre
# City ID: 281, City Name: omboue
# City ID: 282, City Name: zhigansk
# City ID: 283, City Name: palmer
# City ID: 284, City Name: akyab
# City ID: 285, City Name: sai buri
# City ID: 286, City Name: saint george
# City ID: 287, City Name: cabra
# City ID: 288, City Name: teacapan
# City ID: 289, City Name: synya
# City ID: 290, City Name: cururupu
# City ID: 291, City Name: mount gambier
# City ID: 292, City Name: mizdah
# City ID: 293, City Name: tomatlan
# City ID: 294, City Name: imbituba
# City ID: 295, City Name: iqaluit
# City ID: 296, City Name: bandarbeyla
# City ID: 297, City Name: lewisville
# City ID: 298, City Name: ust-tsilma
# City ID: 299, City Name: port-gentil
# City ID: 300, City Name: kongoussi
# City ID: 301, City Name: krasnyy chikoy
# City ID: 302, City Name: tuktoyaktuk
# City ID: 303, City Name: oktyabrskoye
# City ID: 304, City Name: ancud
# City ID: 305, City Name: dobre miasto
# City ID: 306, City Name: camacha
# City ID: 307, City Name: nyurba
# City ID: 308, City Name: semnan
# City ID: 309, City Name: mackenzie
# City ID: 310, City Name: quang ngai
# City ID: 311, City Name: fort frances
# City ID: 312, City Name: hvolsvollur
# City ID: 313, City Name: kaseda
# City ID: 314, City Name: karapyshi
# City ID: 315, City Name: manggar
# City ID: 316, City Name: taoudenni
# City ID: 317, City Name: taperoa
# City ID: 318, City Name: umm bab
# City ID: 319, City Name: vila franca do campo
# City ID: 320, City Name: awbari
# City ID: 321, City Name: waipawa
# City ID: 322, City Name: cedar city
# City ID: 323, City Name: smithers
# City ID: 324, City Name: notre-dame-du-lac
# City ID: 325, City Name: mwingi
# City ID: 326, City Name: clyde river
# City ID: 327, City Name: amahai
# City ID: 328, City Name: swellendam
# City ID: 329, City Name: weligama
# City ID: 330, City Name: farafangana
# City ID: 331, City Name: coahuayana
# City ID: 332, City Name: eucaliptus
# City ID: 333, City Name: carlos chagas
# City ID: 334, City Name: banjarmasin
# City ID: 335, City Name: san juan
# City ID: 336, City Name: chapais
# City ID: 337, City Name: labytnangi
# City ID: 338, City Name: tura
# City ID: 339, City Name: asmar
# City ID: 340, City Name: santa isabel
# City ID: 341, City Name: okuchi
# City ID: 342, City Name: bengkulu
# City ID: 343, City Name: gurupi
# City ID: 344, City Name: presidencia roque saenz pena
# City ID: 345, City Name: alyangula
# City ID: 346, City Name: cayenne
# City ID: 347, City Name: mitu
# City ID: 348, City Name: ayaviri
# City ID: 349, City Name: vung tau
# City ID: 350, City Name: chicama
# City ID: 351, City Name: monterey
# City ID: 352, City Name: oksfjord
# City ID: 353, City Name: saldanha
# City ID: 354, City Name: sola
# City ID: 355, City Name: puerto baquerizo moreno
# City ID: 356, City Name: petropavlovsk-kamchatskiy
# City ID: 357, City Name: illapel
# City ID: 358, City Name: manokwari
# City ID: 359, City Name: zhanaozen
# City ID: 360, City Name: belaya gora
# City ID: 361, City Name: urbano santos
# City ID: 362, City Name: shangzhi
# City ID: 363, City Name: beira
# City ID: 364, City Name: sinnamary
# City ID: 365, City Name: lanzhou
# City ID: 366, City Name: borgarnes
# City ID: 367, City Name: auki
# City ID: 368, City Name: rauma
# City ID: 369, City Name: arlit
# City ID: 370, City Name: martigues
# City ID: 371, City Name: itarema
# City ID: 372, City Name: tilichiki
# City ID: 373, City Name: altamira
# City ID: 374, City Name: vanavara
# City ID: 375, City Name: kokopo
# City ID: 376, City Name: grindavik
# City ID: 377, City Name: vilani
# City ID: 378, City Name: northam
# City ID: 379, City Name: carbonear
# City ID: 380, City Name: ponta delgada
# City ID: 381, City Name: nandgaon
# City ID: 382, City Name: college
# City ID: 383, City Name: boyolangu
# City ID: 384, City Name: disa
# City ID: 385, City Name: umm kaddadah
# City ID: 386, City Name: griffith
# City ID: 387, City Name: bontang
# City ID: 388, City Name: kudahuvadhoo
# City ID: 389, City Name: rudnogorsk
# City ID: 390, City Name: gao
# City ID: 391, City Name: tsnori
# City ID: 392, City Name: rio gallegos
# City ID: 393, City Name: andenes
# City ID: 394, City Name: moen
# City ID: 395, City Name: gogrial
# City ID: 396, City Name: paamiut
# City ID: 397, City Name: belyy
# City ID: 398, City Name: siemiatycze
# City ID: 399, City Name: yar-sale
# City ID: 400, City Name: abu samrah
# City ID: 401, City Name: aklavik
# City ID: 402, City Name: santa ines
# City ID: 403, City Name: jalu
# City ID: 404, City Name: grand-lahou
# City ID: 405, City Name: mahebourg
# City ID: 406, City Name: stephenville
# City ID: 407, City Name: nikolskoye
# City ID: 408, City Name: kinkala
# City ID: 409, City Name: flinders
# City ID: 410, City Name: maua
# City ID: 411, City Name: parabel
# City ID: 412, City Name: muros
# City ID: 413, City Name: yulara
# City ID: 414, City Name: richha
# City ID: 415, City Name: marrakesh
# City ID: 416, City Name: coquimbo
# City ID: 417, City Name: aksu
# City ID: 418, City Name: segezha
# City ID: 419, City Name: olafsvik
# City ID: 420, City Name: constitucion
# City ID: 421, City Name: suclayin
# City ID: 422, City Name: narsaq
# City ID: 423, City Name: goderich
# City ID: 424, City Name: san bartolome de tirajana
# City ID: 425, City Name: jasper
# City ID: 426, City Name: pimenta bueno
# City ID: 427, City Name: ajdabiya
# City ID: 428, City Name: iwanai
# City ID: 429, City Name: nueve de julio
# City ID: 430, City Name: qui nhon
# City ID: 431, City Name: awjilah
# City ID: 432, City Name: banjar
# City ID: 433, City Name: burley
# City ID: 434, City Name: lunel
# City ID: 435, City Name: fortuna
# City ID: 436, City Name: plainview
# City ID: 437, City Name: japura
# City ID: 438, City Name: port lincoln
# City ID: 439, City Name: namatanai
# City ID: 440, City Name: baker city
# City ID: 441, City Name: itoman
# City ID: 442, City Name: moranbah
# City ID: 443, City Name: igarapava
# City ID: 444, City Name: daru
# City ID: 445, City Name: pitimbu
# City ID: 446, City Name: bima
# City ID: 447, City Name: shelburne
# City ID: 448, City Name: oranjemund
# City ID: 449, City Name: los altos
# City ID: 450, City Name: gotsu
# City ID: 451, City Name: ordu
# City ID: 452, City Name: the valley
# City ID: 453, City Name: san cristobal
# City ID: 454, City Name: matara
# City ID: 455, City Name: niono
# City ID: 456, City Name: srivardhan
# City ID: 457, City Name: noumea
# City ID: 458, City Name: road town
# City ID: 459, City Name: romanovskaya
# City ID: 460, City Name: svetlyy
# City ID: 461, City Name: ashta
# City ID: 462, City Name: olinda
# City ID: 463, City Name: hoi an
# City ID: 464, City Name: escarcega
# City ID: 465, City Name: kastamonu
# City ID: 466, City Name: nola
# City ID: 467, City Name: tala
# City ID: 468, City Name: axim
# City ID: 469, City Name: ishigaki
# City ID: 470, City Name: pangai
# City ID: 471, City Name: mundra
# City ID: 472, City Name: rudnichnyy
# City ID: 473, City Name: leningradskiy
# City ID: 474, City Name: caravelas
# City ID: 475, City Name: tres arroyos
# City ID: 476, City Name: itarantim
# City ID: 477, City Name: bereznehuvate
# City ID: 478, City Name: shumskiy
# City ID: 479, City Name: san quintin
# City ID: 480, City Name: mountain home
# City ID: 481, City Name: ostrovnoy
# City ID: 482, City Name: nouadhibou
# City ID: 483, City Name: betare oya
# City ID: 484, City Name: rio muerto
# City ID: 485, City Name: xinye
# City ID: 486, City Name: havre-saint-pierre
# City ID: 487, City Name: rio bonito
# City ID: 488, City Name: vylkove
# City ID: 489, City Name: trapani
# City ID: 490, City Name: praia da vitoria
# City ID: 491, City Name: burns lake
# City ID: 492, City Name: kavaratti
# City ID: 493, City Name: port keats
# City ID: 494, City Name: manchester
# City ID: 495, City Name: makakilo city
# City ID: 496, City Name: luderitz
# City ID: 497, City Name: robertson
# City ID: 498, City Name: barra dos coqueiros
# City ID: 499, City Name: san vicente de chucuri
# City ID: 500, City Name: campbellton
# City ID: 501, City Name: mazagao
# City ID: 502, City Name: lorengau
# City ID: 503, City Name: brazzaville
# City ID: 504, City Name: faanui
# City ID: 505, City Name: ratnagiri
# City ID: 506, City Name: bulgan
# City ID: 507, City Name: portage
# City ID: 508, City Name: mandalgovi
# City ID: 509, City Name: sungaipenuh
# City ID: 510, City Name: mafra
# City ID: 511, City Name: timaru
# City ID: 512, City Name: egvekinot
# City ID: 513, City Name: kulhudhuffushi
# City ID: 514, City Name: lata
# City ID: 515, City Name: spornoye
# City ID: 516, City Name: alta floresta
# City ID: 517, City Name: haines junction
# City ID: 518, City Name: west point
# City ID: 519, City Name: sisimiut
# City ID: 520, City Name: benguela
# City ID: 521, City Name: tiznit
# City ID: 522, City Name: divnomorskoye
# City ID: 523, City Name: oistins
# City ID: 524, City Name: owando
# City ID: 525, City Name: basco
# City ID: 526, City Name: bartica
# City ID: 527, City Name: sakaraha
# City ID: 528, City Name: bairiki
# City ID: 529, City Name: bela
# City ID: 530, City Name: airai
# City ID: 531, City Name: half moon bay
# City ID: 532, City Name: de panne
# City ID: 533, City Name: osoyoos
# City ID: 534, City Name: oparino
# City ID: 535, City Name: victor harbor
# City ID: 536, City Name: wanning
# City ID: 537, City Name: yaransk
# City ID: 538, City Name: vardo
# City ID: 539, City Name: neiafu
# City ID: 540, City Name: peniche
# City ID: 541, City Name: santa isabel do rio negro
# City ID: 542, City Name: quatre cocos
# City ID: 543, City Name: booue
# City ID: 544, City Name: sibu
# City ID: 545, City Name: wad rawah
# City ID: 546, City Name: savannah bight
# City ID: 547, City Name: dunedin
# City ID: 548, City Name: mogadishu
# City ID: 549, City Name: chernyshevskiy
# City ID: 550, City Name: talavera de la reina
# City ID: 551, City Name: bure
# City ID: 552, City Name: wangkui
# City ID: 553, City Name: lodwar
# City ID: 554, City Name: mujiayingzi
# City ID: 555, City Name: le port
# City ID: 556, City Name: ardakan
# City ID: 557, City Name: burnie
# City ID: 558, City Name: kawalu
# City ID: 559, City Name: kutum
# City ID: 560, City Name: laguna
# City ID: 561, City Name: cuiaba
# City ID: 562, City Name: tubuala
# City ID: 563, City Name: hudson bay
# City ID: 564, City Name: buraydah
# City ID: 565, City Name: sao sebastiao do paraiso
# City ID: 566, City Name: barreirinhas
# City ID: 567, City Name: kifri
# City ID: 568, City Name: sambava
# City ID: 569, City Name: pingliang
# City ID: 570, City Name: tena
# City ID: 571, City Name: los llanos de aridane
# City ID: 572, City Name: maniitsoq
# City ID: 573, City Name: mamou
# City ID: 574, City Name: sao paulo de olivenca
# City ID: 575, City Name: dryden
# City ID: 576, City Name: martapura
# City ID: 577, City Name: hohhot
# City ID: 578, City Name: vila velha
# City ID: 579, City Name: meybod
# City ID: 580, City Name: karratha
# City ID: 581, City Name: ulladulla
# City ID: 582, City Name: pathein
# City ID: 583, City Name: biloela
# City ID: 584, City Name: severo-yeniseyskiy
# City ID: 585, City Name: shirokiy
# City ID: 586, City Name: mrakovo
# City ID: 587, City Name: waingapu
# City ID: 588, City Name: lensk
# City ID: 589, City Name: bac lieu
# City ID: 590, City Name: porto velho
# City ID: 591, City Name: dedougou
# City ID: 592, City Name: mpongwe
# City ID: 593, City Name: mersing
# City ID: 594, City Name: evensk
# City ID: 595, City Name: christchurch
# City ID: 596, City Name: prabumulih
# City ID: 597, City Name: vadso
# City ID: 598, City Name: bracebridge
# City ID: 599, City Name: aldan
# City ID: 600, City Name: do gonbadan
# City ID: 601, City Name: talcahuano
# City ID: 602, City Name: coffs harbour
# City ID: 603, City Name: disna
# City ID: 604, City Name: lahaina
# City ID: 605, City Name: houma
# City ID: 606, City Name: baracoa
# City ID: 607, City Name: bolu
# City ID: 608, City Name: necochea
# City ID: 609, City Name: padang
# City ID: 610, City Name: iracoubo
# City ID: 611, City Name: easley
# City ID: 612, City Name: yokadouma
# City ID: 613, City Name: tolaga bay
# City ID: 614, City Name: maningrida
# City ID: 615, City Name: liberal
# City ID: 616, City Name: bobcaygeon
# City ID: 617, City Name: lourdes
# City ID: 618, City Name: fairbanks
# City ID: 619, City Name: mecca
# City ID: 620, City Name: crowthorne
# City ID: 621, City Name: blackwater
# City ID: 622, City Name: dalby
# City ID: 623, City Name: aykhal
# City ID: 624, City Name: san patricio
# City ID: 625, City Name: abha
# City ID: 626, City Name: kaeo
# City ID: 627, City Name: kayerkan
# City ID: 628, City Name: bitung
# City ID: 629, City Name: kushima
# City ID: 630, City Name: luanda
# City ID: 631, City Name: kavieng
# City ID: 632, City Name: fuchu
# City ID: 633, City Name: muroto
# City ID: 634, City Name: saint-gaudens
# City ID: 635, City Name: umm lajj
# City ID: 636, City Name: borogontsy
# City ID: 637, City Name: sri aman
# City ID: 638, City Name: nakatunguru
# City ID: 639, City Name: anadyr
# City ID: 640, City Name: fort nelson
# City ID: 641, City Name: genhe
# City ID: 642, City Name: mayumba
# City ID: 643, City Name: matagami
# City ID: 644, City Name: adelaide
# City ID: 645, City Name: buchanan
# City ID: 646, City Name: nuevo imperial
# City ID: 647, City Name: sechura
# City ID: 648, City Name: ballarat
# City ID: 649, City Name: gusinoye ozero
# City ID: 650, City Name: saint peter
# City ID: 651, City Name: gallup
# City ID: 652, City Name: nador
# City ID: 653, City Name: dalbandin
# City ID: 654, City Name: tautira
# City ID: 655, City Name: almaznyy
# City ID: 656, City Name: maltahohe
# City ID: 657, City Name: consett
# City ID: 658, City Name: cervo
# City ID: 659, City Name: kenai
# City ID: 660, City Name: leh
# City ID: 661, City Name: marmande
# City ID: 662, City Name: usolye-sibirskoye
# City ID: 663, City Name: colares
# City ID: 664, City Name: batagay
# City ID: 665, City Name: bugene
# City ID: 666, City Name: port moresby
# City ID: 667, City Name: kousseri
# City ID: 668, City Name: hervey bay
# City ID: 669, City Name: sidi ali
# City ID: 670, City Name: koumac
# City ID: 671, City Name: bushehr
# City ID: 672, City Name: bheramara
# City ID: 673, City Name: tukrah
# City ID: 674, City Name: gumdag
# City ID: 675, City Name: ibra
# City ID: 676, City Name: santa barbara
# City ID: 677, City Name: scarborough
# City ID: 678, City Name: falkenberg
# City ID: 679, City Name: tricase
# City ID: 680, City Name: stokmarknes
# City ID: 681, City Name: balakhninskiy
# City ID: 682, City Name: hovd
# City ID: 683, City Name: leshukonskoye
# City ID: 684, City Name: suibara
# City ID: 685, City Name: salamiyah
# City ID: 686, City Name: conde
# City ID: 687, City Name: samarai
# City ID: 688, City Name: louga
# City ID: 689, City Name: pajan
# City ID: 690, City Name: suntar
# City ID: 691, City Name: isehara
# City ID: 692, City Name: bida
# City ID: 693, City Name: yilan
# City ID: 694, City Name: bubaque
# City ID: 695, City Name: ladario
# City ID: 696, City Name: biak
# City ID: 697, City Name: san vicente
# City ID: 698, City Name: harper
# City ID: 699, City Name: belle fourche
# City ID: 700, City Name: longyan
# City ID: 701, City Name: samana
# City ID: 702, City Name: naze
# City ID: 703, City Name: bentong
# City ID: 704, City Name: mayenne
# City ID: 705, City Name: shingu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create data frame

weather_dict = {
    "City ID": city_id_list,
    "City": cityname_list,
    "Cloudiness": cloudiness_list,
    "Country": country_list,
    "Date": date_list,
    "Humidity": humidity_list,
    "Lat": lat_list,
    "Lng": lng_list,
    "Max Temp": max_temp_list,
    "Wind Speed": wind_list
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#    City ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0     saumur         100      FR  1602986173        93  47.33
# 1        1    hualmay          13      PE  1602986175        85 -11.10
# 2        2     hobart          75      AU  1602986102        54 -42.88
# 3        3  esperance           0      AU  1602986179        67 -33.87
# 4        4      praia          20      CV  1602986181        94  14.92
#
#       Lng  Max Temp  Wind Speed
# 0   -0.25     46.99        5.59
# 1  -77.61     62.37        8.93
# 2  147.33     61.00        6.93
# 3  121.90     60.80       11.41
# 4  -23.51     77.00        4.70

# %%
#save data frame to csv file

weather_df.to_csv("output/city_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# find out if any cities have humidity over 100%

high_humidity_count = len(weather_df[weather_df["Humidity"] > 100])
print(f"Number of cities in list with humidity over 100%: {high_humidity_count}")
# Out:
# Number of cities in list with humidity over 100%: 0

# %%
#  Get the indices of cities that have humidity over 100% and drop them from the dataframe

if high_humidity_count > 0:
    index = weather_df[weather_df["Humidity"] > 100].index
    weather_df = weather_df.drop(index)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_data = weather_df["Lat"]

max_temp_data = weather_df["Max Temp"]

plt.scatter(lat_data, max_temp_data, marker="o", edgecolors="black")
plt.title(f"City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperatue (F)")
plt.savefig("output/plot1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity_data = weather_df["Humidity"]

plt.scatter(lat_data, humidity_data, marker="o", edgecolors="black")
plt.title(f"City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudiness_data = weather_df["Cloudiness"]

plt.scatter(lat_data, cloudiness_data, marker="o", edgecolors="black")
plt.title(f"City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
wind_data = weather_df["Wind Speed"]

plt.scatter(lat_data, wind_data, marker="o", edgecolors="black")
plt.title(f"City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# create dataframes for northern & southern hemisperes

north_df = weather_df.loc[weather_df["Lat"] >= 0]
north_lat = north_df["Lat"]

south_df = weather_df.loc[weather_df["Lat"] < 0]
south_lat = south_df["Lat"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
max_temp_n = north_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, max_temp_n)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(north_lat, max_temp_n, marker="o", edgecolors="black")
plt.plot(north_lat,regress_values,"r-")
plt.title(f"Northern Hemisphere:\n City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperatue (F)")
plt.show()

correlation = st.pearsonr(north_lat, max_temp_n)
print(f"Linear Regression Model: {line_eq}")
print(f"The correlation coefficient is {round(correlation[0],2)}")
# Out:
# Linear Regression Model: y = -0.92x + 91.68
# The correlation coefficient is -0.89

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
